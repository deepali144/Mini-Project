# %% [markdown]
# <a href="https://colab.research.google.com/github/deepali144/Mini-Project/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# ...
# time: 177 µs

# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("african elephants",limit=30,output_dir='images',adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://media.buzzle.com/media/images-en/photos/mammals/elephants/1200-37926192-male-african-elephant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://upload.wikimedia.org/wikipedia/commons/b/b1/African_Elephant_8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.joinaikido.com/wp-content/uploads/2013/07/African_Bush_Elephant_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Loxodonta_africana_-_old_bull_(Ngorongoro%2C_2009).jpg/1200px-Loxodonta_africana_-_old_bull_(Ngorongoro%2C_2009).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://haydensanimalfacts.files.wordpress.com/2014/05/african-elephant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://4.bp.blogspot.com/-pvdq6WIcALo/UO6p08qT0yI/AAAAAAAAAWM/Mq1j-YC4z5I/s1600/elephant.JPG
# ...

# %%
from bing_image_downloader import downloader
downloader.download("royal enfield",limit=30,output_dir='images',adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 13 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://bikeadvice.in/wp-content/uploads/2017/09/Royal-Enfield-Classic-500-Stealth-Black-Pics-8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://bd.gaadicdn.com/upload/userfiles/images/5df8accca1cb7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://gaadiwaadi.com/wp-content/uploads/2017/05/Royal-Enfield-Bullet-350-Custom-by-Jedi-7-960x640.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.wallpapersin4k.org/wp-content/uploads/2017/04/Bullet-Classic-350-Black-Wallpaper-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://pictures.topspeed.com/IMG/jpg/200608/avon-safety-mileage-.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://pakistani.pk/uploads/reviews/photos/original/b8/67/79/1202-99-1434027890.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("eagle",limit=30,output_dir='images',adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 13 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.englishsalvage.co.uk/upload/images/shopprod/majestic-composition-stone-eagle-finials_18249_pic4_size3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.warrelics.eu/forum/attachments/art-decor-exotica-third-reich/993161d1472337793-nazi-eagle-desk-decoration-20160821_091420.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://in.gov/dnr/fishwild/images/fw-deer-in-pasture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://interiorgod.com/wp-content/uploads/2016/04/Elegant-Victorian-Style-Dining-Room-Designs.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://catacombs.space1999.net/main/images/cast/spmayapose5s.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://cdn.onlyinyourstate.com/wp-content/uploads/2017/02/5195762066_a44fd55df1_o-700x1064.jpg
# [%] File Downloaded !
#
# ...

# %%
import numpy as np
a = np.array([1,2])
a
# Out:
# array([1, 2])
# time: 10.9 ms

# %%
import numpy as np
a= np.array([1,2,3,4,5])
a.ndim
# Out:
# 1
# time: 6.09 ms

# %%
import numpy as np
a = np.array([[1,2,3,4,5],
              [4,5,6,7,8]])
a.ndim
# Out:
# 2
# time: 4.3 ms

# %%
a.flatten()
# Out:
# array([1, 2, 3, 4, 5, 4, 5, 6, 7, 8])
# time: 2.96 ms

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['african elephant','eagle','royal enfield']
for category in CATEGORIES:
  print(category)
# Out:
# african elephant
# eagle
# royal enfield
# time: 3.26 ms

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['african elephant','eagle','royal enfield']
for category in CATEGORIES:
   class_num = CATEGORIES.index(category)
   print(class_num)
# Out:
# 0
# 1
# 2
# time: 4.63 ms

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['african elephant','eagle','royal enfield']
for category in CATEGORIES:
   class_num = CATEGORIES.index(category)
   path = os.path.join(DATADIR,category)
   print(path)
# Out:
# /content/images/african elephant
# /content/images/eagle
# /content/images/royal enfield
# time: 8.18 ms

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['african elephant','eagle','royal enfield']
for category in CATEGORIES:
   class_num = CATEGORIES.index(category)
   path = os.path.join(DATADIR,category)
for img in os.listdir(path):
     img_array = imread(os.path.join(path,img))
     print(img_array)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# [[[ 20   6   6]
#   [ 20   6   6]
#   [ 19   7   7]
#   ...
#   [174  64  27]
#   [169  63  23]
#   [167  61  19]]
#
#  [[ 19   5   5]
#   [ 20   6   6]
#   [ 17   5   5]
#   ...
#   [175  67  29]
#   [169  66  25]
#   [167  64  21]]
#
#  [[ 19   5   5]
#   [ 19   5   5]
# ...

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['african elephant','eagle','royal enfield']
for category in CATEGORIES:
   class_num = CATEGORIES.index(category)
   path = os.path.join(DATADIR,category)
for img in os.listdir(path):
     img_array = imread(os.path.join(path,img))
     print(img_array.shape)
# Out:
# (450, 299, 3)
# (1536, 2048, 3)
# (1080, 1920, 3)
# (417, 748, 3)
# (800, 1200, 3)
# (533, 800, 3)
# (1080, 1920, 3)
# (537, 331, 3)
# (450, 299, 3)
# (410, 728, 3)
# (537, 331, 3)
# (533, 800, 3)
# (1487, 2227, 3)
# (1487, 2227, 3)
# (500, 1000, 3)
# (417, 748, 3)
# (640, 960, 3)
# (720, 1280, 3)
# (533, 800, 3)
# (800, 1200, 3)
# (410, 728, 3)
# (1080, 1920, 3)
# (1536, 2048, 3)
# (720, 1280, 3)
# (640, 960, 3)
# (720, 1280, 3)
# (450, 299, 3)
# (640, 960, 3)
# (1080, 1920, 3)
# (500, 1000, 3)
# time: 681 ms

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['african elephant','eagle','royal enfield']
for category in CATEGORIES:
   class_num = CATEGORIES.index(category)
   path = os.path.join(DATADIR,category)
for img in os.listdir(path):
     img_array = imread(os.path.join(path,img))
     plt.imshow(img_array)
     break
# Out:
# time: 186 ms

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['african elephant','eagle','royal enfield']
for category in CATEGORIES:
   class_num = CATEGORIES.index(category)
   path = os.path.join(DATADIR,category)
for img in os.listdir(path):
     img_array = imread(os.path.join(path,img))
     img_resized = resize(img_array,(150,150,3))
     flat_data.append(img_resized.flatten())
     images.append(img_resized)
     target.append(class_num)

flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)
# Out:
# time: 6.32 s

# %%
flat_data
# Out:
# array([[1.        , 1.        , 1.        , ..., 1.        , 1.        ,
#         1.        ],
#        [0.07138248, 0.02352941, 0.02088889, ..., 0.05782013, 0.03137255,
#         0.01960784],
#        [0.        , 0.00392157, 0.01960784, ..., 0.02819608, 0.02819608,
#         0.03603922],
#        ...,
#        [0.95686275, 0.94003922, 0.62562092, ..., 0.08584314, 0.05054902,
#         0.06231373],
#        [0.        , 0.00392157, 0.01960784, ..., 0.02819608, 0.02819608,
#         0.03603922],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]])
# time: 4.06 ms

# %%
flat_data[0]
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])
# time: 5.29 ms

# %%
len(flat_data[0])
# Out:
# 67500
# time: 2.74 ms

# %%
150*150*3
# Out:
# 67500
# time: 2.31 ms

# %%
target
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2])
# time: 4.81 ms

# %%
np.unique(target,return_counts=True)
# Out:
# (array([2]), array([30]))
# time: 5.34 ms

# %%
unique,counts = np.unique(target,return_counts=True)
plt.bar(CATEGORIES,counts)
# Out:
# <BarContainer object of 3 artists>
# time: 131 ms

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(flat_data,target,
                              test_size=0.3,random_state=109)
# Out:
# time: 43.2 ms

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm
param_grid = [
           {'C':[1,10,100,1000],'kernel':['linear']},
           {'C':[1,10,100,1000],'gamma':[0.001,0.0001],'kernel':['rbf']},
]
svc = svm.SVC(probability=True)
clf = GridSearchCV(svc,param_grid)
# Out:
# time: 2.28 ms

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
# Out:
# time: 983 µs

# %%
import pickle
pickle.dump(clf,open('img_model.p','wb'))
# Out:
# time: 1.67 ms

# %%
model = pickle.load(open('img_model.p','rb'))
# Out:
# time: 1.49 ms

# %%
flat_data = []
url = input('Enter your URL')
img_resize = resize(img,(150,150,3))
flat_data.append(img_resized.flatten())
flat_data = np.array(flat_data)
print(img.shape)
plt.imshow(img_resized)
y_out = model.predict(flat_data)
y_out = CATEGORIES[y_out[0]]
print(f'PREDICTED OUTPUT:'{y_out})
# Out:
# Enter your URLhttps://image.shutterstock.com/image-illustration/bald-eagle-flying-swoop-hand-260nw-1076887982.jpg
# (280, 527, 3)
# time: 59.3 s
